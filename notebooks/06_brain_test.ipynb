# %%
import sys
import os

# 1. Setup Path
sys.path.append(os.path.abspath("../src"))

# 2. Inject Credentials (The Engine Fuel)
os.environ["GEMINI_API_KEY"] = "AIzaSyC66cprj8k8AZUo6Pu8Li19ohXxl1jssBQ"
# ESA Credentials
os.environ["EODAG__COPERNICUS_DATASPACE__AUTH__CREDENTIALS__USERNAME"] = "rjgupta2116@gmail.com"
os.environ["EODAG__COPERNICUS_DATASPACE__AUTH__CREDENTIALS__PASSWORD"] = "Netra_Project.2026"
os.environ["EODAG__COPERNICUS_DATASPACE__PRIORITY"] = "1"

# ISRO Credentials
os.environ["BHOONIDHI_USER"] = "rjgupta2116"
os.environ["BHOONIDHI_PASS"] = "netra@2026"

# 3. Load the Brain
from graph.workflow import create_netra_graph

print("🚀 Booting up NETRA Unified Agent...")
netra_brain = create_netra_graph()

# 4. Run the Mission
initial_state = {
    "query": "Find satellite images of New York City for December 2024",
    "parameters": {},
    "results": [],
    "final_response": "",
    "errors": []
}

print("\n--- MISSION START ---")
final_state = netra_brain.invoke(initial_state)
print("--- MISSION COMPLETE ---\n")

# 5. Report
print(f"📊 Total Images Found: {len(final_state['results'])}")
print("-" * 30)
for img in final_state['results']:
    print(f"🌍 Source: {img['source']}")
    print(f"ID: {img['id']}")
    print("-" * 30)

if final_state['errors']:
    print("\n⚠️ ERRORS ENCOUNTERED:")
    for err in final_state['errors']:
        print(f"- {err}")
